# %%
print('hi')
# Out:
# hi

# %%
age = 50
if age >= 18:
    print('老逼登')
else:
    print('小逼崽子')
# Out:
# 老逼登

# %%
hungry = 100
while hungry > 0:
    print('吃个蛋')
    print('还剩', hungry, '的饥饿值')
    hungry -= 10
# Out:
# 吃个蛋
# 还剩 100 的饥饿值
# 吃个蛋
# 还剩 90 的饥饿值
# 吃个蛋
# 还剩 80 的饥饿值
# 吃个蛋
# 还剩 70 的饥饿值
# 吃个蛋
# 还剩 60 的饥饿值
# 吃个蛋
# 还剩 50 的饥饿值
# 吃个蛋
# 还剩 40 的饥饿值
# 吃个蛋
# 还剩 30 的饥饿值
# 吃个蛋
# 还剩 20 的饥饿值
# 吃个蛋
# 还剩 10 的饥饿值
